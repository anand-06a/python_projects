# %%
# Simple Billing System

def generate_bill():
    total = 0

    print("===== BILLING SYSTEM =====")

    while True:
        item = input("Enter item name: ")
        price = float(input("Enter item price: ₹"))
        quantity = int(input("Enter quantity: "))

        amount = price * quantity
        total += amount

        print(f"{item}: ₹{price} x {quantity} = ₹{amount}")

        choice = input("Add another item? (yes/no): ").lower()

        if choice != "yes":
            break

    print("\n===== FINAL BILL =====")
    print(f"Total Amount: ₹{total}")

    gst = total * 0.18   # 18% GST
    final_amount = total + gst

    print(f"GST (18%): ₹{gst:.2f}")
    print(f"Grand Total: ₹{final_amount:.2f}")
    print("=======================")


# Call the function
generate_bill()
# Out:
# ===== BILLING SYSTEM =====
# Enter item name: pen
# Enter item price: ₹10
# Enter quantity: 20
# pen: ₹10.0 x 20 = ₹200.0
# Add another item? (yes/no): yes
# Enter item name: Books
# Enter item price: ₹50
# Enter quantity: 15
# Books: ₹50.0 x 15 = ₹750.0
# Add another item? (yes/no): no
#
# ===== FINAL BILL =====
# Total Amount: ₹950.0
# GST (18%): ₹171.00
# Grand Total: ₹1121.00
# =======================
